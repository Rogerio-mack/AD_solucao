# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/AD_solucao/blob/main/Aula_02_Cars93_exploracao_inicial_solucao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/MASS/Cars93.csv")
df.drop(columns="rownames",inplace=True)
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0           31                 NaN      Front  ...          5     177
# 1           25  Driver & Passenger      Front  ...          5     195
# 2           26         Driver only      Front  ...          5     180
# 3           26  Driver & Passenger      Front  ...          6     193
# 4           30         Driver only       Rear  ...          4     186
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %% [markdown]
# # Exploração Inicial (Conhecendo os Dados)

# %%
df.head() # df.tail()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0           31                 NaN      Front  ...          5     177
# 1           25  Driver & Passenger      Front  ...          5     195
# 2           26         Driver only      Front  ...          5     180
# 3           26  Driver & Passenger      Front  ...          6     193
# 4           30         Driver only       Rear  ...          4     186
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
df[ df.Manufacturer == 'Volvo' ]
# Out:
#    Manufacturer Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 91        Volvo   240  Compact       21.8   22.7       23.5        21
# 92        Volvo   850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 91           28         Driver only       Rear  ...          5     190
# 92           28  Driver & Passenger      Front  ...          5     184
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 91        104     67           37           29.5          14.0    2985
# 92        105     69           38           30.0          15.0    3245
#
#      Origin       Make
# 91  non-USA  Volvo 240
# 92  non-USA  Volvo 850
#
# [2 rows x 27 columns]

# %%
df.shape
# Out:
# (93, 27)

# %%
len(df)
# Out:
# 93

# %%
df.dtypes
# Out:
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                 object
# Make                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        93 non-null     object
#  1   Model               93 non-null     object
#  2   Type                93 non-null     object
#  3   Min.Price           93 non-null     float64
#  4   Price               93 non-null     float64
#  5   Max.Price           93 non-null     float64
#  6   MPG.city            93 non-null     int64
#  7   MPG.highway         93 non-null     int64
#  8   AirBags             59 non-null     object
#  9   DriveTrain          93 non-null     object
#  10  Cylinders           93 non-null     object
#  11  EngineSize          93 non-null     float64
#  12  Horsepower          93 non-null     int64
#  13  RPM                 93 non-null     int64
#  14  Rev.per.mile        93 non-null     int64
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Min.Price', 'Price', 'Max.Price',
#        'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain', 'Cylinders',
#        'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Man.trans.avail',
#        'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width',
#        'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight', 'Origin',
#        'Make'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count  93.000000  93.000000  93.000000  93.000000    93.000000   93.000000
# mean   17.125806  19.509677  21.898925  22.365591    29.086022    2.667742
# std     8.746029   9.659430  11.030457   5.619812     5.331726    1.037363
# min     6.700000   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%    10.800000  12.200000  14.700000  18.000000    26.000000    1.800000
# 50%    14.700000  17.700000  19.600000  21.000000    28.000000    2.400000
# 75%    20.300000  23.300000  25.300000  25.000000    31.000000    3.300000
# max    45.400000  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   93.000000    93.000000     93.000000           93.000000   93.000000
# mean   143.827957  5280.645161   2332.204301           16.664516    5.086022
# ...

# %%
df.describe(include="all")
# Out:
#        Manufacturer    Model     Type  Min.Price      Price  Max.Price  \
# count            93       93       93  93.000000  93.000000  93.000000
# unique           32       93        6        NaN        NaN        NaN
# top       Chevrolet  Integra  Midsize        NaN        NaN        NaN
# freq              8        1       22        NaN        NaN        NaN
# mean            NaN      NaN      NaN  17.125806  19.509677  21.898925
# std             NaN      NaN      NaN   8.746029   9.659430  11.030457
# min             NaN      NaN      NaN   6.700000   7.400000   7.900000
# 25%             NaN      NaN      NaN  10.800000  12.200000  14.700000
# 50%             NaN      NaN      NaN  14.700000  17.700000  19.600000
# 75%             NaN      NaN      NaN  20.300000  23.300000  25.300000
# max             NaN      NaN      NaN  45.400000  61.900000  80.000000
#
#          MPG.city  MPG.highway      AirBags DriveTrain  ... Passengers  \
# ...

# %% [markdown]
# # Seleção básica de dados

# %%
df.Manufacturer
# Out:
# 0          Acura
# 1          Acura
# 2           Audi
# 3           Audi
# 4            BMW
#          ...
# 88    Volkswagen
# 89    Volkswagen
# 90    Volkswagen
# 91         Volvo
# 92         Volvo
# Name: Manufacturer, Length: 93, dtype: object

# %%
df.Manufacturer.value_counts()
# Out:
# Manufacturer
# Chevrolet        8
# Ford             8
# Dodge            6
# Mazda            5
# Pontiac          5
# Oldsmobile       4
# Hyundai          4
# Buick            4
# Nissan           4
# Toyota           4
# Volkswagen       4
# Subaru           3
# Honda            3
# Geo              2
# Audi             2
# Acura            2
# Volvo            2
# Mitsubishi       2
# Mercedes-Benz    2
# Lexus            2
# Chrysler         2
# Cadillac         2
# Eagle            2
# Lincoln          2
# Mercury          2
# Infiniti         1
# BMW              1
# Chrylser         1
# Plymouth         1
# Saab             1
# Saturn           1
# Suzuki           1
# Name: count, dtype: int64

# %%
df.Price
# Out:
# 0     15.9
# 1     33.9
# 2     29.1
# 3     37.7
# 4     30.0
#       ...
# 88    19.7
# 89    20.0
# 90    23.3
# 91    22.7
# 92    26.7
# Name: Price, Length: 93, dtype: float64

# %%
df.Price.mean()
# Out:
# np.float64(19.50967741935484)

# %%
df[ df.Manufacturer == 'Chevrolet' ]
# Out:
#    Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11    Chevrolet    Cavalier  Compact        8.5   13.4       18.3        25
# 12    Chevrolet     Corsica  Compact       11.4   11.4       11.4        25
# 13    Chevrolet      Camaro   Sporty       13.4   15.1       16.8        19
# 14    Chevrolet      Lumina  Midsize       13.4   15.9       18.4        21
# 15    Chevrolet  Lumina_APV      Van       14.7   16.3       18.0        18
# 16    Chevrolet       Astro      Van       14.7   16.6       18.6        15
# 17    Chevrolet     Caprice    Large       18.0   18.8       19.6        17
# 18    Chevrolet    Corvette   Sporty       34.6   38.0       41.5        17
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 11           36                 NaN      Front  ...          5     182
# 12           34         Driver only      Front  ...          5     184
# ...

# %% [markdown]
# # Qual o preço médio dos veículos Chevrolet?

# %%
Chevrolet = df[ df.Manufacturer == 'Chevrolet' ]

# %%
Chevrolet.head()
# Out:
#    Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11    Chevrolet    Cavalier  Compact        8.5   13.4       18.3        25
# 12    Chevrolet     Corsica  Compact       11.4   11.4       11.4        25
# 13    Chevrolet      Camaro   Sporty       13.4   15.1       16.8        19
# 14    Chevrolet      Lumina  Midsize       13.4   15.9       18.4        21
# 15    Chevrolet  Lumina_APV      Van       14.7   16.3       18.0        18
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 11           36                 NaN      Front  ...          5     182
# 12           34         Driver only      Front  ...          5     184
# 13           28  Driver & Passenger       Rear  ...          4     193
# 14           29                 NaN      Front  ...          6     198
# 15           23                 NaN      Front  ...          7     178
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
Chevrolet.describe()
# Out:
#        Min.Price      Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# count   8.000000   8.000000   8.000000   8.00000     8.000000    8.000000
# mean   16.087500  18.187500  20.325000  19.62500    27.625000    3.600000
# std     7.966078   8.304463   8.921683   3.73927     5.370222    1.353303
# min     8.500000  11.400000  11.400000  15.00000    20.000000    2.200000
# 25%    12.900000  14.675000  17.700000  17.00000    24.500000    2.200000
# 50%    14.050000  16.100000  18.350000  18.50000    27.000000    3.600000
# 75%    15.525000  17.150000  18.850000  22.00000    30.250000    4.475000
# max    34.600000  38.000000  41.500000  25.00000    36.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count    8.000000     8.000000      8.000000            8.000000    8.000000
# mean   161.875000  4775.000000   1965.625000           19.100000    5.375000
# ...

# %%
Chevrolet.Price.mean()
# Out:
# np.float64(18.1875)

# %%
df[ df.Manufacturer == 'Chevrolet' ].Price.mean()
# Out:
# np.float64(18.1875)

# %%
#
# prompt: Dê o price médio dos veículos Chevrolet de df
df[ df.Manufacturer == 'Chevrolet' ].Price.mean()
# Out:
# np.float64(18.1875)

# %% [markdown]
# # Exercício
#
# 1. Faça uma exploração inicial dos dados de `penguins` em https://github.com/INRIA/scikit-learn-mooc/tree/main/datasets
#
# 2. Obtenha o nome das espécies de penguins
#
# 3. Obtenha o peso médio de cada espécie

# %%
df = pd.read_csv("https://raw.githubusercontent.com/INRIA/scikit-learn-mooc/main/datasets/penguins.csv")
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
# ...

# %%
df.Species.value_counts()
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64

# %% [markdown]
# ### Notas
#
# - `.unique()` e iterações
# - `df.field_A` = `df["field_A"]` = `cpo ="field_A"` + `df[cpo]`
# - Solução alternativa com `groupby()`

# %%
for specie in df.Species.unique():
    print(f'{specie},: {df[ df.Species == specie ]["Body Mass (g)"].mean():.2f}')
# Out:
# Adelie Penguin (Pygoscelis adeliae),: 3700.66
# Gentoo penguin (Pygoscelis papua),: 5076.02
# Chinstrap penguin (Pygoscelis antarctica),: 3733.09

# %%
df.groupby("Species")["Body Mass (g)"].mean()
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          3700.662252
# Chinstrap penguin (Pygoscelis antarctica)    3733.088235
# Gentoo penguin (Pygoscelis papua)            5076.016260
# Name: Body Mass (g), dtype: float64
